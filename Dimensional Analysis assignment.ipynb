# %%
import math
import matplotlib.pyplot as plt
import numpy as np


T = [.1,.24,.38,.52,.66,.8,.94,1.08,1.22,1.36,1.5,1.65,1.79,1.93,3.26,3.53,3.8,4.07,4.34,4.61,15.0,25.0,34.0,53.0,62.0]
R = [11.1,19.9,25.4,28.8,31.9,34.2,36.3,38.9,41.0,42.8,44.4,46.0,46.9,48.7,59.0,61.1,62.9,64.3,65.6,67.3,106.5,130.0,145.0,175.0,185.0]
Tsecs =[]
#I change the units of T from msecs to secs.
for i in T:
    j=i/1000
    Tsecs.append(j)
print Tsecs

logR = []
logT = []

for i in Tsecs:
     logT.append(math.log(i))

for i in R:
     logR.append(math.log(i))

plt.scatter(T,R)
plt.show()

plt.scatter(logT,logR)
plt.show()

m,b = np.polyfit(logT, logR, 1)
print "m=", m
print "b=", b
# Out:
# [0.0001, 0.00023999999999999998, 0.00038, 0.0005200000000000001, 0.00066, 0.0008, 0.00094, 0.00108, 0.00122, 0.00136, 0.0015, 0.00165, 0.0017900000000000001, 0.0019299999999999999, 0.00326, 0.0035299999999999997, 0.0038, 0.004070000000000001, 0.00434, 0.00461, 0.015, 0.025, 0.034, 0.053, 0.062]
# m= 0.4058226251
# b= 6.39367141358
